# %% [markdown]
# ## 1. 연간 교통사고 데이터

# %%
import pandas as pd

# %%
a=pd.read_csv('frequentzoneOldman.csv')

# %% [markdown]
# ### 연도별 지역별, 총 발생통계를 나타내줍니다, 위도 경도 정보도 들어있습니다. (연간데이터 입니다.)

# %%
a
# Out:
#      year sidocode guguncode  occrrnc_cnt           동  caslt_cnt  dth_dnv_cnt  \
# 0    2015       서울       강남구            5  서울특별시 강남구1          5            0
# 1    2015       서울       강남구            3  서울특별시 강남구2          3            0
# 2    2015       서울       강동구            7  서울특별시 강동구1          7            0
# 3    2015       서울       강동구            3  서울특별시 강동구2          3            0
# 4    2015       서울       강북구            9  서울특별시 강북구1         10            0
# ..    ...      ...       ...          ...         ...        ...          ...
# 832  2021       서울        중구            5   서울특별시 중구2          5            1
# 833  2021       서울        중구            5   서울특별시 중구3          5            0
# 834  2021       서울       중랑구            5  서울특별시 노원구1          6            1
# 835  2021       서울       중랑구            5  서울특별시 노원구2          7            0
# 836  2021       서울       중랑구            5  서울특별시 노원구3          5            0
#
# ...

# %%
# 중구 만 뽑기
a=a[a['guguncode']=='중구']

# %%
a
# Out:
#      year sidocode guguncode  occrrnc_cnt          동  caslt_cnt  dth_dnv_cnt  \
# 130  2015       서울        중구            7  서울특별시 중구1          7            1
# 131  2015       서울        중구            7  서울특별시 중구2          7            0
# 132  2015       서울        중구            6  서울특별시 중구3          6            1
# 133  2015       서울        중구            6  서울특별시 중구4          7            0
# 134  2015       서울        중구            4  서울특별시 중구5          4            1
# 135  2015       서울        중구            4  서울특별시 중구6          5            0
# 136  2015       서울        중구            3  서울특별시 중구7          3            0
# 281  2016       서울        중구            6  서울특별시 중구1          7            1
# 282  2016       서울        중구            5  서울특별시 중구2         12            0
# 283  2016       서울        중구            2  서울특별시 중구3          2            2
# 416  2017       서울        중구            5  서울특별시 중구1          5            0
# ...

# %%
## 중구만 뽑으려면
## please get summation of every year for only columns occrrnc_cnt,caslt_cnt	dth_dnv_cnt	se_dnv_cnt	sl_dnv_cnt	wnd_dnv_cn
a=a[['year','occrrnc_cnt','caslt_cnt','dth_dnv_cnt','se_dnv_cnt','sl_dnv_cnt','wnd_dnv_cnt']].groupby('year').sum()
## only sum of occrrnc_cnt,caslt_cnt	dth_dnv_cnt	se_dnv_cnt	sl_dnv_cnt	wnd_dnv_cn
# Out:
#       occrrnc_cnt  caslt_cnt  dth_dnv_cnt  se_dnv_cnt  sl_dnv_cnt  wnd_dnv_cnt
# year
# 2015           37         39            3          24           9            3
# 2016           13         21            3          10           4            4
# 2017           16         19            0          11           6            2
# 2018           13         15            3           8           2            2
# 2019            8          8            2           4           2            0
# 2020           19         19            0          12           4            3
# 2021           16         16            1          15           0            0

# %% [markdown]
# ## 2. 서울 이동데이터(일별)

# %%
b=pd.read_csv('total_data.csv')

# %%
b
# Out:
#             기준일ID  시간대구분 자치구코드       총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0        20170101      0    중구  189272.8069      5839.7737        2145.9994
# 1        20170101      1    중구  165315.2581      4953.2301        1899.6020
# 2        20170101      2    중구  160031.6010      5016.0501        1918.1388
# 3        20170101      3    중구  158427.1590      4932.0504        1889.1525
# 4        20170101      4    중구  157119.6148      4945.0435        1886.6234
# ...           ...    ...   ...          ...            ...              ...
# 1293307  20221231     19   강동구  495518.4903     20055.0019       11342.5474
# 1293308  20221231     20   강동구  500961.9211     20124.8521       11397.6765
# 1293309  20221231     21   강동구  506973.6962     20301.8894       11527.1939
# 1293310  20221231     22   강동구  513082.1424     20575.2582       11680.7128
# 1293311  20221231     23   강동구  515174.1517     20892.5856       11790.0818
#
# ...

# %% [markdown]
# ## 일별, 시간대별 지역별 이동데이터입니다, 자치구코드 11110-> 중구 같은건 다 바꿔두었고, 일별데이터임을 활용하면 좋을 것 같습니다.

# %%
#예를들어, 중구 데이터만 뽑아보겠습니다.a

jungu=b[b['자치구코드']=='중구']

# %%
jungu
# Out:
#             기준일ID  시간대구분 자치구코드       총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0        20170101      0    중구  189272.8069      5839.7737        2145.9994
# 1        20170101      1    중구  165315.2581      4953.2301        1899.6020
# 2        20170101      2    중구  160031.6010      5016.0501        1918.1388
# 3        20170101      3    중구  158427.1590      4932.0504        1889.1525
# 4        20170101      4    중구  157119.6148      4945.0435        1886.6234
# ...           ...    ...   ...          ...            ...              ...
# 1091827  20221231     19    중구  229317.7276      6900.2475        2513.9030
# 1091828  20221231     20    중구  211170.8063      6350.6496        2340.0874
# 1091829  20221231     21    중구  196161.8597      5733.7772        2143.0917
# 1091830  20221231     22    중구  181366.1006      5714.8676        2149.0503
# 1091831  20221231     23    중구  161747.7282      4719.3118        1843.6104
#
# ...

# %% [markdown]
# ### 이런식으로 모든 데이터에 대해 비슷하게 활용하면 좋을 것 같아요
