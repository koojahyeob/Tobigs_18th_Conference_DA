# %%
import pandas as pd
data=pd.read_csv('seoul_moving_data/2020/LOCAL_PEOPLE_GU_2020'+'.csv',encoding='cp949')

# %%
code_area=data['자치구코드'].unique()

data_for_codes=[]
for code in code_area:
    data_for_codes.append(data[data['자치구코드']==code])

# %%
data_for_codes[0]
# Out:
#          기준일ID     시간대구분  자치구코드  총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0            0  20200101      0   11110    248283.0355        6496.6713
# 1            1  20200101      0   11140    187720.0184        4655.7791
# 2            2  20200101      0   11170    292640.2683        7594.5578
# 3            3  20200101      0   11200    333267.7444       12520.2471
# 4            4  20200101      0   11215    390059.2798       12015.7622
# ...        ...       ...    ...     ...            ...              ...
# 219020  219020  20201231      0   11620    507001.9987       12164.0629
# 219021  219021  20201231      0   11650    477590.9221       18835.3884
# 219022  219022  20201231      0   11680    640635.3217       23343.8937
# 219023  219023  20201231      0   11710    740483.6204       30161.6678
# 219024  219024  20201231      0   11740    531141.9549       21201.8427
#
#         남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# ...
