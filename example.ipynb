# %%
import pandas as pd

final=pd.read_csv('final.csv')

# %%
final.head()
# Out:
#             x          y       h3_address  \
# 0  126.981851  37.583372  8930e1dab47ffff
# 1  127.037602  37.638996  8930e1c2287ffff
# 2  127.087740  37.600075  8930e1c038fffff
# 3  127.086163  37.548920  8930e1c1e43ffff
# 4  127.052611  37.474410  8930e1c846fffff
#
#                                           neighbours  \
# 0  ['8930e1dab0bffff', '8930e1dab57ffff', '8930e1...
# 1  ['8930e1c2287ffff', '8930e1c2297ffff', '8930e1...
# 2  ['8930e1c0313ffff', '8930e1c038bffff', '8930e1...
# 3  ['8930e1c1e57ffff', '8930e1c1e43ffff', '8930e1...
# 4  ['8930e1c846bffff', '8930e1c80d7ffff', '8930e1...
#
#                                 neighbours_centroids  caslt_cnt  dth_dnv_cnt  \
# 0  [(37.58613392049726, 126.98056894996715), (37....          0            0
# 1  [(37.63901298097283, 127.03741299155716), (37....          5            0
# 2  [(37.59689598894049, 127.08903919595633), (37....          0            0
# ...

# %%
final.sum()
# Out:
# x                                                           152392.343303
# y                                                            45069.530261
# h3_address              8930e1dab47ffff8930e1c2287ffff8930e1c038fffff8...
# neighbours              ['8930e1dab0bffff', '8930e1dab57ffff', '8930e1...
# neighbours_centroids    [(37.58613392049726, 126.98056894996715), (37....
# caslt_cnt                                                            1475
# dth_dnv_cnt                                                            80
# se_dnv_cnt                                                            850
# sl_dnv_cnt                                                            489
# wnd_dnv_cnt                                                            56
# caslt_cnt_1                                                          1155
# dth_dnv_cnt_1                                                          76
# se_dnv_cnt_1                                                          649
# ...
